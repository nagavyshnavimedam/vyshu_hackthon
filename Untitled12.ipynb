# %% [markdown]
# <a href="https://colab.research.google.com/github/nagavyshnavimedam/vyshu_hackthon/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
df=pd.read_csv('/content/members.csv')

# %%
df.head()
# Out:
#    id first_name    surname sex                   email  city_id  \
# 0   1      Ollie     Kinney   M   Ol.Kinney@walla.co.il        4
# 1   2     Landon     Bishop   F         La.Bi@gmail.com        4
# 2   3        Jia   Delarosa   M        Jia.De@gmail.com        4
# 3   4  Valentina  Ratcliffe   F  Va.Ratcliffe@gmail.com        4
# 4   5     Stacie      Patel   F    St.Patel@hotmail.com        3
#
#    monthly_budget
# 0          1000.0
# 1           500.0
# 2           500.0
# 3           600.0
# 4           500.0

# %%
df.tail()
# Out:
#       id first_name  surname sex                 email  city_id  \
# 195  196       Juan   Barlow   M     Juan.Ba@yahoo.com        4
# 196  197    Natalia   Daniel   F  Natalia.Da@gmail.com        4
# 197  198       Drew    Begum   M  Drew.Begum@gmail.com        3
# 198  199       Nial  Meadows   M     Nial.Me@yahoo.com        5
# 199  200       Diya    Myers   F   Diya.My@walla.co.il        5
#
#      monthly_budget
# 195           500.0
# 196           500.0
# 197           800.0
# 198           500.0
# 199           600.0

# %%
df.dropna()
# Out:
#       id first_name    surname sex                   email  city_id  \
# 0      1      Ollie     Kinney   M   Ol.Kinney@walla.co.il        4
# 1      2     Landon     Bishop   F         La.Bi@gmail.com        4
# 2      3        Jia   Delarosa   M        Jia.De@gmail.com        4
# 3      4  Valentina  Ratcliffe   F  Va.Ratcliffe@gmail.com        4
# 4      5     Stacie      Patel   F    St.Patel@hotmail.com        3
# ..   ...        ...        ...  ..                     ...      ...
# 195  196       Juan     Barlow   M       Juan.Ba@yahoo.com        4
# 196  197    Natalia     Daniel   F    Natalia.Da@gmail.com        4
# 197  198       Drew      Begum   M    Drew.Begum@gmail.com        3
# 198  199       Nial    Meadows   M       Nial.Me@yahoo.com        5
# 199  200       Diya      Myers   F     Diya.My@walla.co.il        5
#
#      monthly_budget
# 0            1000.0
# 1             500.0
# 2             500.0
# 3             600.0
# 4             500.0
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              200 non-null    int64
#  1   first_name      200 non-null    object
#  2   surname         200 non-null    object
#  3   sex             200 non-null    object
#  4   email           200 non-null    object
#  5   city_id         200 non-null    int64
#  6   monthly_budget  200 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 11.1+ KB

# %%
print(df.shape)
# Out:
# (200, 7)

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'surname', 'sex', 'email', 'city_id',
#        'monthly_budget'],
#       dtype='object')

# %%
print('missing values')
df.isnull().sum()
# Out:
# missing values
# id                0
# first_name        0
# surname           0
# sex               0
# email             0
# city_id           0
# monthly_budget    0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       id first_name    surname sex                   email  city_id  \
# 0      1      Ollie     Kinney   M   Ol.Kinney@walla.co.il        4
# 1      2     Landon     Bishop   F         La.Bi@gmail.com        4
# 2      3        Jia   Delarosa   M        Jia.De@gmail.com        4
# 3      4  Valentina  Ratcliffe   F  Va.Ratcliffe@gmail.com        4
# 4      5     Stacie      Patel   F    St.Patel@hotmail.com        3
# ..   ...        ...        ...  ..                     ...      ...
# 195  196       Juan     Barlow   M       Juan.Ba@yahoo.com        4
# 196  197    Natalia     Daniel   F    Natalia.Da@gmail.com        4
# 197  198       Drew      Begum   M    Drew.Begum@gmail.com        3
# 198  199       Nial    Meadows   M       Nial.Me@yahoo.com        5
# 199  200       Diya      Myers   F     Diya.My@walla.co.il        5
#
#      monthly_budget
# 0            1000.0
# 1             500.0
# 2             500.0
# 3             600.0
# 4             500.0
# ..              ...
# ...

# %%
len(df)
# Out:
# 200

# %%
selected_features=['city_id,monthly_budget']

# %%
x=df['city_id']
y=df['monthly_budget']

# %%
x_train,x_test,y_train,y_test=train_test_split(x.values.reshape(-1,1),y,test_size=0.2,random_state=30)

# %%
model=RandomForestClassifier(n_estimators=100)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy}")
# Out:
# Accuracy:0.325

# %%
print(len(x_test)),print(len(y_pred))
# Out:
# 40
# 40
# (None, None)

# %%
plt.scatter(df['city_id'],df['monthly_budget'])
plt.xlabel("city_id")
plt.ylabel("monthly_budget")
plt.show()
